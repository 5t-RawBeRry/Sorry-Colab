# %%
#@title **检查显卡**
# !nvidia-smi

# %%
#@title **安装 NovalAI** 

# %cd /content/
# !apt install -qq -y byobu aria2
# !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar
# !echo "Decompressing..."
# !tar xf naifu.tar && rm naifu.tar
# !echo "Done"

# %%
#@title **配置依赖 NovalAI** 

# %cd /content/naifu
# !pip install virtualenv && bash ./setup.sh
# !sed -i 's/# export SAVE_FILES="1"/export SAVE_FILES="1"/g' run.sh
# !sed -i 's/& bore local 6969 --to bore.pub//g' run.sh
# !sed -i 's/from pytorch_lightning.utilities.distributed import rank_zero_only/from pytorch_lightning.utilities.rank_zero import rank_zero_only/g' run.sh

# %%
#@title **6969 NGROK** [Auth Token Ngrok](https://dashboard.ngrok.com/get-started/your-authtoken)
# !wget https://raw.githubusercontent.com/5t-RawBeRry/Sorry-Colab/main/sh/6969.sh && chmod +x 6969.sh && ./6969.sh

# %%
#@title **运行它！**
# %cd /content/naifu
# !echo "您的访问地址~"
# !curl --silent --show-error http://127.0.0.1:4040/api/tunnels | sed -nE 's/.*public_url":"tcp:..([^"]*).*/\1/p'
# !echo '请等待出现 0.0.0.0:6969 之后再访问访问地址~'
# !bash run.sh

# %% [markdown]
# **保持连接持久**
#
# Press F12 >>> Select Console>>> Paste this code
# ```
# function ClickConnect() {
#   console.log('Working')
#   document
#     .querySelector('#top-toolbar > colab-connect-button')
#     .shadowRoot.querySelector('#connect')
#     .click()
# }
#
# setInterval(ClickConnect, 60000)

# %%
#@title **SSH NGROK （默认关闭）** [Auth Token Ngrok](https://dashboard.ngrok.com/get-started/your-authtoken)

#!wget https://raw.githubusercontent.com/5t-RawBeRry/Sorry-Colab/main/sh/ssh.sh && chmod +x ssh.sh && ./ssh.sh
